# %%
import numpy as np
import pickle
import datetime
import pandas as pd

# %%
allData = pd.read_csv('FirstICU_MinAge.csv',index_col=0)
allData
# Out:
# E:\Anaconda\envs\pgmpy\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          C.SUBJECT_ID            II.INTIME  C.HADM_ID  C.ICUSTAY_ID  D.ITEMID  \
# 0                 109  2141-06-11 10:17:54     147469        253139    220045
# 1                 109  2141-06-11 10:17:54     147469        253139    220045
# 2                 109  2141-06-11 10:17:54     147469        253139    220045
# 3                 109  2141-06-11 10:17:54     147469        253139    220045
# 4                 109  2141-06-11 10:17:54     147469        253139    220045
# ...               ...                  ...        ...           ...       ...
# 2207256         99992  2144-07-25 18:04:42     197084        242052    223791
# 2207257         99992  2144-07-25 18:04:42     197084        242052    223791
# ...

# %% [markdown]
# # 查看各个变量情况
# ## 根据《默沙东诊疗手册》

# %%
allData[allData['VARIABLE']=='temp']  # 体温 (华氏度 F)     正常范围  36-37.3 摄氏度C
# Out:
#          C.SUBJECT_ID            II.INTIME  C.HADM_ID  C.ICUSTAY_ID  D.ITEMID  \
# 217               109  2141-06-11 10:17:54     147469        253139    223761
# 218               109  2141-06-11 10:17:54     147469        253139    223761
# 219               109  2141-06-11 10:17:54     147469        253139    223761
# 220               109  2141-06-11 10:17:54     147469        253139    223761
# 221               109  2141-06-11 10:17:54     147469        253139    223761
# ...               ...                  ...        ...           ...       ...
# 2207138         99992  2144-07-25 18:04:42     197084        242052    223761
# 2207139         99992  2144-07-25 18:04:42     197084        242052    223761
# 2207140         99992  2144-07-25 18:04:42     197084        242052    223761
# 2207141         99992  2144-07-25 18:04:42     197084        242052    223761
# 2207142         99992  2144-07-25 18:04:42     197084        242052    223761
#
# ...

# %%
allData[allData['VARIABLE']=='ALT']  # 丙氨酸转氨酶 (IU/L)      正常范围 0-35U/L,   IU = U
# Out:
#          C.SUBJECT_ID            II.INTIME  C.HADM_ID  C.ICUSTAY_ID  D.ITEMID  \
# 376               109  2141-06-11 10:17:54     147469        253139    220644
# 632               111  2144-07-01 04:13:59     155897        249202    220644
# 3027              124  2166-01-09 13:05:18     138376        256064    220644
# 3028              124  2166-01-09 13:05:18     138376        256064    220644
# 3029              124  2166-01-09 13:05:18     138376        256064    220644
# ...               ...                  ...        ...           ...       ...
# 2201240         99863  2142-04-02 22:04:30     100749        216757    220644
# 2201241         99863  2142-04-02 22:04:30     100749        216757    220644
# 2206125         99923  2201-02-23 20:43:12     164914        202505    220644
# 2206403         99939  2110-03-22 04:05:55     159023        252442    220644
# 2206404         99939  2110-03-22 04:05:55     159023        252442    220644
#
# ...

# %%
allData[allData['VARIABLE']=='AST']  # 天门冬氨酸氨基转移酶(谷草转氨酶)(IU/L)       正常范围  0-35U/L
# Out:
#          C.SUBJECT_ID            II.INTIME  C.HADM_ID  C.ICUSTAY_ID  D.ITEMID  \
# 350               109  2141-06-11 10:17:54     147469        253139    220587
# 625               111  2144-07-01 04:13:59     155897        249202    220587
# 2935              124  2166-01-09 13:05:18     138376        256064    220587
# 2936              124  2166-01-09 13:05:18     138376        256064    220587
# 2937              124  2166-01-09 13:05:18     138376        256064    220587
# ...               ...                  ...        ...           ...       ...
# 2201137         99863  2142-04-02 22:04:30     100749        216757    220587
# 2201138         99863  2142-04-02 22:04:30     100749        216757    220587
# 2206118         99923  2201-02-23 20:43:12     164914        202505    220587
# 2206389         99939  2110-03-22 04:05:55     159023        252442    220587
# 2206390         99939  2110-03-22 04:05:55     159023        252442    220587
#
# ...

# %%
allData[allData['VARIABLE']=='BUN']  #尿素氮(mg/dL)         正常范围  8～20 mg/dL
# Out:
#          C.SUBJECT_ID            II.INTIME  C.HADM_ID  C.ICUSTAY_ID  D.ITEMID  \
#
# 242               109  2141-06-11 10:17:54     147469        253139    220277
# 243               109  2141-06-11 10:17:54     147469        253139    220277
# 244               109  2141-06-11 10:17:54     147469        253139    220277
# 245               109  2141-06-11 10:17:54     147469        253139    220277
# 246               109  2141-06-11 10:17:54     147469        253139    220277
# ...               ...                  ...        ...           ...       ...
# 2207183         99992  2144-07-25 18:04:42     197084        242052    220277
# 2207184         99992  2144-07-25 18:04:42     197084        242052    220277
# 2207185         99992  2144-07-25 18:04:42     197084        242052    220277
# 2207186         99992  2144-07-25 18:04:42     197084        242052    220277
# 2207187         99992  2144-07-25 18:04:42     197084        242052    220277
#
# ...

# %% [markdown]
# # 以上查看完毕

# %%
# 只保留 24 小时之内做的检测数据
allData = allData[allData['final_24hr']==1]

# %%
allData['VARIABLE'].unique()
# Out:
# array(['hr', 'resp', 'temp', 'spo2', 'AST', 'CL', 'creatinine', 'GLU',
#        'ALT', 'Na', 'BUN', 'TBIL', 'K', 'hco3', 'Hemoglobin', 'HCT',
#        'WBC', 'NEUT', 'PLT', 'PT', 'PTT', 'INR', 'MEANBP', 'ABP', 'gcs',
#        'pain', 'po2', 'pco2', 'ALB', 'peep', 'airway', 'RR', 'FiO2',
#        'THR'], dtype=object)

# %%
# 取 24 小时内 检测的平均值
df = allData[['C.SUBJECT_ID','VARIABLE','C.VALUENUM']]
df = df.groupby(by=['C.SUBJECT_ID','VARIABLE'],as_index=False).mean()
df
# Out:
#        C.SUBJECT_ID VARIABLE  C.VALUENUM
# 0               109      ABP  213.666667
# 1               109      ALT   80.000000
# 2               109      AST  136.000000
# 3               109      BUN   48.000000
# 4               109       CL  110.333333
# ...             ...      ...         ...
# 75750         99992       hr   68.521739
# 75751         99992     pain    2.000000
# 75752         99992     resp   15.695652
# 75753         99992     spo2   92.739130
# 75754         99992     temp   97.550000
#
# [75755 rows x 3 columns]

# %%
two_level_index_series = df.set_index(['C.SUBJECT_ID','VARIABLE'])['C.VALUENUM']
print(two_level_index_series)
# Out:
# C.SUBJECT_ID  VARIABLE
# 109           ABP         213.666667
#               ALT          80.000000
#               AST         136.000000
#               BUN          48.000000
#               CL          110.333333
#                              ...
# 99992         hr           68.521739
#               pain          2.000000
#               resp         15.695652
#               spo2         92.739130
#               temp         97.550000
# Name: C.VALUENUM, Length: 75755, dtype: float64

# %%
new_df = two_level_index_series.unstack()
# print(new_df)
# 可以通过 rename_axis(index=, columns=) 来给坐标轴重命名
new_df = new_df.rename_axis(columns=None)
new_df
# Out:
#                      ABP  ALB   ALT    AST    BUN          CL  FiO2  \
# C.SUBJECT_ID
# 109           213.666667  NaN  80.0  136.0   48.0  110.333333   NaN
# 111                  NaN  1.9  45.0   52.0   30.5  125.500000   NaN
# 124                  NaN  NaN   NaN    NaN  107.5  117.000000   NaN
# 188                  NaN  3.7  41.0   65.0   29.5  116.500000   NaN
# 222                  NaN  NaN   NaN    NaN   19.0  104.000000   NaN
# ...                  ...  ...   ...    ...    ...         ...   ...
# 99899                NaN  NaN   NaN    NaN   41.0   92.000000   NaN
# 99923                NaN  1.9  75.0  125.0   79.0   91.500000   NaN
# 99939         161.625000  3.2  18.0   16.0  142.5  105.000000   NaN
# 99973                NaN  NaN   NaN    NaN   18.5  116.500000   NaN
# 99992                NaN  NaN   NaN    NaN   56.0  104.000000   NaN
#
#                      GLU        HCT  Hemoglobin  ...       gcs  hco3  \
# C.SUBJECT_ID                                     ...
# ...

# %%
# 这里我们只给列重命名, 没有给索引重命名, 至于原因请往下看
new_df = new_df.reset_index()
new_df
# Out:
#       C.SUBJECT_ID         ABP  ALB   ALT    AST    BUN          CL  FiO2  \
# 0              109  213.666667  NaN  80.0  136.0   48.0  110.333333   NaN
# 1              111         NaN  1.9  45.0   52.0   30.5  125.500000   NaN
# 2              124         NaN  NaN   NaN    NaN  107.5  117.000000   NaN
# 3              188         NaN  3.7  41.0   65.0   29.5  116.500000   NaN
# 4              222         NaN  NaN   NaN    NaN   19.0  104.000000   NaN
# ...            ...         ...  ...   ...    ...    ...         ...   ...
# 3266         99899         NaN  NaN   NaN    NaN   41.0   92.000000   NaN
# 3267         99923         NaN  1.9  75.0  125.0   79.0   91.500000   NaN
# 3268         99939  161.625000  3.2  18.0   16.0  142.5  105.000000   NaN
# 3269         99973         NaN  NaN   NaN    NaN   18.5  116.500000   NaN
# 3270         99992         NaN  NaN   NaN    NaN   56.0  104.000000   NaN
#
#              GLU        HCT  ...       gcs  hco3         hr   pain  \
# ...

# %%
# 导入 患者的结局信息
death_df = pd.read_csv('all_data_DeathOrNot.csv',index_col=0)
death_df = death_df[['C.SUBJECT_ID','Death']]
death_df
# Out:
#          C.SUBJECT_ID  Death
# 0                 109      0
# 1                 109      0
# 2                 109      0
# 3                 109      0
# 4                 109      0
# ...               ...    ...
# 3967270         17190      0
# 3967271         40978      0
# 3967272         67675      0
# 3967273         73074      1
# 3967274         92525      0
#
# [3967275 rows x 2 columns]

# %%
death_df = death_df.drop_duplicates()
death_df = death_df[death_df['Death']==1]
death_df   # 死了 705 个人
# Out:
#          C.SUBJECT_ID  Death
# 1253              109      1
# 1272              111      1
# 1296              124      1
# 2222              188      1
# 2789              305      1
# ...               ...    ...
# 613596          99899      1
# 1960377         32805      1
# 1967333         88587      1
# 1968272         96181      1
# 2039288         94817      1
#
# [705 rows x 2 columns]

# %%
# new_df.merge(death_df,on='C.SUBJECT_ID',how='left')  # 不能用  merge 因为会有重复的数据，一个人先生后死
new_df['Death'] = new_df['C.SUBJECT_ID'].apply(lambda x : 1 if x in death_df['C.SUBJECT_ID'].values else 0)
new_df[new_df['Death']==1]
# Out:
#       C.SUBJECT_ID         ABP   ALB   ALT    AST         BUN          CL  \
# 0              109  213.666667   NaN  80.0  136.0   48.000000  110.333333
# 1              111         NaN  1.90  45.0   52.0   30.500000  125.500000
# 2              124         NaN   NaN   NaN    NaN  107.500000  117.000000
# 3              188         NaN  3.70  41.0   65.0   29.500000  116.500000
# 6              305         NaN   NaN  80.0   96.0  102.000000  102.000000
# ...            ...         ...   ...   ...    ...         ...         ...
# 3256         99756         NaN   NaN  38.0   74.0   21.000000  107.000000
# 3257         99768         NaN  2.15  42.5   79.0   48.333333  122.333333
# 3260         99817  115.200000  2.50  51.5  104.5   52.000000  108.000000
# 3261         99822         NaN   NaN   NaN    NaN   19.250000   94.000000
# 3266         99899         NaN   NaN   NaN    NaN   41.000000   92.000000
#
#       FiO2         GLU        HCT  ...       hco3          hr      pain  \
# ...

# %%
((new_df.isnull().sum())/new_df.shape[0]).sort_values(ascending=False).map(lambda x:"{:.2%}".format(x))
# Out:
# FiO2            99.94%
# RR              99.91%
# THR             99.72%
# airway          95.60%
# ABP             75.76%
# MEANBP          74.66%
# peep            67.75%
# ALB             61.60%
# po2             55.33%
# NEUT            54.88%
# pco2            51.54%
# ALT             46.56%
# AST             46.53%
# TBIL            46.13%
# PTT             22.71%
# PT              21.13%
# INR             21.13%
# pain            19.32%
# PLT              2.72%
# WBC              2.72%
# Hemoglobin       2.69%
# HCT              2.14%
# GLU              1.68%
# hco3             1.62%
# BUN              1.62%
# CL               1.59%
# creatinine       1.53%
# Na               1.25%
# K                1.22%
# temp             0.89%
# gcs              0.58%
# resp             0.55%
# spo2             0.55%
# hr               0.49%
# C.SUBJECT_ID     0.00%
# Death            0.00%
# dtype: object

# %%
#删除所有样本中缺失值超过30%的行
def del_rows(data):
    t = int(0.7*data.shape[1])
    data = data.dropna(thresh=t)#保留至少有 t 个非空的行
    #data = data[(data.T != 0).any()]
    return data
#删除所有行中缺失值超过30%的列
def remcolumns(data):
    t = int(0.7*data.shape[0])
    data = data.dropna(thresh=t,axis=1)#保留至少有 t 个非空的列
    #data = data.loc[:, (data != 0).any(axis=0)]
    return data

# %%
del_rows_df = del_rows(new_df)
((del_rows_df.isnull().sum())/del_rows_df.shape[0]).sort_values(ascending=False).map(lambda x:"{:.2%}".format(x))
# Out:
# FiO2            99.90%
# RR              99.84%
# THR             99.58%
# airway          92.70%
# ABP             62.93%
# MEANBP          61.37%
# peep            53.28%
# ALB             44.53%
# NEUT            41.19%
# po2             36.39%
# pco2            33.32%
# TBIL            18.72%
# ALT             18.61%
# AST             18.51%
# pain            15.22%
# PTT              4.54%
# PT               3.08%
# INR              3.08%
# temp             0.52%
# WBC              0.10%
# PLT              0.05%
# Hemoglobin       0.05%
# HCT              0.05%
# spo2             0.05%
# BUN              0.05%
# hr               0.00%
# resp             0.00%
# C.SUBJECT_ID     0.00%
# hco3             0.00%
# gcs              0.00%
# creatinine       0.00%
# Na               0.00%
# K                0.00%
# GLU              0.00%
# CL               0.00%
# Death            0.00%
# dtype: object

# %%
# del_rows_df[del_rows_df['Death']==1]  # 只剩 497 个死亡患者
# del_rows_df[del_rows_df['Death']==0]    # 只剩 1421 个 生存患者
del_rows_df.to_csv('del_rows_df.csv')
del_rows_df
# Out:
#       C.SUBJECT_ID         ABP  ALB   ALT    AST    BUN          CL  FiO2  \
# 0              109  213.666667  NaN  80.0  136.0   48.0  110.333333   NaN
# 1              111         NaN  1.9  45.0   52.0   30.5  125.500000   NaN
# 2              124         NaN  NaN   NaN    NaN  107.5  117.000000   NaN
# 3              188         NaN  3.7  41.0   65.0   29.5  116.500000   NaN
# 7              357         NaN  NaN  19.0   20.0   24.5  110.000000   NaN
# ...            ...         ...  ...   ...    ...    ...         ...   ...
# 3260         99817  115.200000  2.5  51.5  104.5   52.0  108.000000   NaN
# 3262         99847         NaN  NaN   NaN    NaN   28.0  103.000000   NaN
# 3263         99863  193.900000  NaN   NaN    NaN   13.5  105.000000   NaN
# 3267         99923         NaN  1.9  75.0  125.0   79.0   91.500000   NaN
# 3268         99939  161.625000  3.2  18.0   16.0  142.5  105.000000   NaN
#
#              GLU   HCT  ...  hco3          hr      pain        pco2      peep  \
# ...

# %%
del_rows_df = pd.read_csv('del_rows_df.csv',index_col=0)
del_rows_df
# Out:
#       C.SUBJECT_ID         ABP  ALB   ALT    AST    BUN          CL  FiO2  \
# 0              109  213.666667  NaN  80.0  136.0   48.0  110.333333   NaN
# 1              111         NaN  1.9  45.0   52.0   30.5  125.500000   NaN
# 2              124         NaN  NaN   NaN    NaN  107.5  117.000000   NaN
# 3              188         NaN  3.7  41.0   65.0   29.5  116.500000   NaN
# 7              357         NaN  NaN  19.0   20.0   24.5  110.000000   NaN
# ...            ...         ...  ...   ...    ...    ...         ...   ...
# 3260         99817  115.200000  2.5  51.5  104.5   52.0  108.000000   NaN
# 3262         99847         NaN  NaN   NaN    NaN   28.0  103.000000   NaN
# 3263         99863  193.900000  NaN   NaN    NaN   13.5  105.000000   NaN
# 3267         99923         NaN  1.9  75.0  125.0   79.0   91.500000   NaN
# 3268         99939  161.625000  3.2  18.0   16.0  142.5  105.000000   NaN
#
#              GLU   HCT  ...  hco3          hr      pain        pco2      peep  \
# ...

# %%
remcolumns(del_rows_df) # 死 497， 生 1421
# Out:
#       C.SUBJECT_ID   ALT    AST    BUN          CL         GLU   HCT  \
# 0              109  80.0  136.0   48.0  110.333333  101.666667  23.6
# 1              111  45.0   52.0   30.5  125.500000  119.000000  40.4
# 2              124   NaN    NaN  107.5  117.000000  118.000000  28.7
# 3              188  41.0   65.0   29.5  116.500000  240.500000  28.1
# 7              357  19.0   20.0   24.5  110.000000  143.000000  25.7
# ...            ...   ...    ...    ...         ...         ...   ...
# 3260         99817  51.5  104.5   52.0  108.000000  102.500000  28.2
# 3262         99847   NaN    NaN   28.0  103.000000  169.500000  26.1
# 3263         99863   NaN    NaN   13.5  105.000000  282.666667  47.7
# 3267         99923  75.0  125.0   79.0   91.500000  115.500000  31.5
# 3268         99939  18.0   16.0  142.5  105.000000  163.500000  22.4
#
#       Hemoglobin    INR      K  ...        WBC  creatinine       gcs  hco3  \
# ...

# %%
del_cols_df = remcolumns(new_df)
  # 死 705 ，生 2566
del_rows(del_cols_df)
# Out:
#       C.SUBJECT_ID    BUN          CL         GLU        HCT  Hemoglobin  \
# 0              109   48.0  110.333333  101.666667  23.600000    7.300000
# 1              111   30.5  125.500000  119.000000  40.400000   13.100000
# 2              124  107.5  117.000000  118.000000  28.700000    9.850000
# 3              188   29.5  116.500000  240.500000  28.100000    9.200000
# 4              222   19.0  104.000000   95.000000  22.800000    7.700000
# ...            ...    ...         ...         ...        ...         ...
# 3266         99899   41.0   92.000000  126.000000  19.400000    6.600000
# 3267         99923   79.0   91.500000  115.500000  31.500000   10.800000
# 3268         99939  142.5  105.000000  163.500000  22.400000    7.866667
# 3269         99973   18.5  116.500000   91.000000  29.000000    9.350000
# 3270         99992   56.0  104.000000  110.000000  28.933333   11.000000
#
#         INR      K          Na    PLT  ...        WBC  creatinine       gcs  \
# ...

# %%
del_cols_df.to_csv('del_cols_df.csv')

# %%
del_cols_df=pd.read_csv('del_cols_df.csv',index_col=0)
del_cols_df
# Out:
#       C.SUBJECT_ID    BUN          CL         GLU        HCT  Hemoglobin  \
# 0              109   48.0  110.333333  101.666667  23.600000    7.300000
# 1              111   30.5  125.500000  119.000000  40.400000   13.100000
# 2              124  107.5  117.000000  118.000000  28.700000    9.850000
# 3              188   29.5  116.500000  240.500000  28.100000    9.200000
# 4              222   19.0  104.000000   95.000000  22.800000    7.700000
# ...            ...    ...         ...         ...        ...         ...
# 3266         99899   41.0   92.000000  126.000000  19.400000    6.600000
# 3267         99923   79.0   91.500000  115.500000  31.500000   10.800000
# 3268         99939  142.5  105.000000  163.500000  22.400000    7.866667
# 3269         99973   18.5  116.500000   91.000000  29.000000    9.350000
# 3270         99992   56.0  104.000000  110.000000  28.933333   11.000000
#
#         INR      K          Na    PLT  ...        WBC  creatinine       gcs  \
# ...

# %% [markdown]
# ## 现在就有两种情况：1、删除了缺失率过多的患者；2、删除了缺失率过多的字段。

# %%
# del_rows_df  # 1
# del_cols_df  # 2

# %% [markdown]
# ## 使用随机森林对缺失值进行插补

# %%
# 准备需要的包
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## 去掉缺失值过多的行，后进行插补的结果

# %%
# data = pd.read_excel(r"C:\Users\xw\Desktop\预测数据.xlsx")# 导入原始数据
data = remcolumns(del_rows_df)
data = data.reset_index()
# data = del_cols_df
target = data['gcs']
# 这里的‘gcs’是指没有数据缺失的那一列的名称，选取一列即可
# 如果每一列的数据都缺失了，可以再创建一列都是1的完整数据并填写名称
features = data.iloc[:,1:-1]
#注意这里没有我没有取最后一列，可根据自己的情况改动

# %%
features
# Out:
#       C.SUBJECT_ID   ALT    AST    BUN          CL         GLU   HCT  \
# 0              109  80.0  136.0   48.0  110.333333  101.666667  23.6
# 1              111  45.0   52.0   30.5  125.500000  119.000000  40.4
# 2              124   NaN    NaN  107.5  117.000000  118.000000  28.7
# 3              188  41.0   65.0   29.5  116.500000  240.500000  28.1
# 4              357  19.0   20.0   24.5  110.000000  143.000000  25.7
# ...            ...   ...    ...    ...         ...         ...   ...
# 1913         99817  51.5  104.5   52.0  108.000000  102.500000  28.2
# 1914         99847   NaN    NaN   28.0  103.000000  169.500000  26.1
# 1915         99863   NaN    NaN   13.5  105.000000  282.666667  47.7
# 1916         99923  75.0  125.0   79.0   91.500000  115.500000  31.5
# 1917         99939  18.0   16.0  142.5  105.000000  163.500000  22.4
#
#       Hemoglobin    INR      K  ...  TBIL        WBC  creatinine       gcs  \
# ...

# %%
X_full, y_full = features,target
n_samples = X_full.shape[0] # 样本
n_features = X_full.shape[1] # 特征
print(n_samples)
print(n_features)
 
#首先确定我们希望放入的缺失值数据的比例，在这里我假设是50%，可以自己改动
rng = np.random.RandomState(0)
missing_rate = 0.5
n_missing_samples = int(np.floor(n_samples * n_features *missing_rate))
#np.floor  向下取整
#所有数据要随机遍布在数据集的各行各列当中，而一个确实的数据会需要一盒行索引和一个列索引
#如果能够创造一个数组，就可以利用索引来赋空值
 
X_missing_reg = X_full.copy()
# 查看缺失情况
missing = X_missing_reg .isna().sum()
missing = pd.DataFrame(data={'特征': missing.index,'缺失值个数':missing.values})
#通过~取反，选取不包含数字0的行
missing = missing[~missing['缺失值个数'].isin([0])]
# 缺失比例
missing['缺失比例'] =  missing['缺失值个数']/X_missing_reg .shape[0]
# print(missing['缺失比例'])
X_df = X_missing_reg.isnull().sum()
# 得出列名 缺失值最少的列名 到 缺失值最多的列名
colname = X_df[~X_df.isin([0])].sort_values().index.values
colname
# Out:
# 1918
# 24
# array(['BUN', 'HCT', 'Hemoglobin', 'PLT', 'spo2', 'WBC', 'temp', 'INR',
#        'PT', 'PTT', 'pain', 'AST', 'ALT', 'TBIL'], dtype=object)

# %%
# 缺失值从小到大的特征顺序
sortindex = []
for i in colname:
    sortindex.append(X_missing_reg.columns.tolist().index(str(i)))
# 遍历所有的特征，从缺失最少的开始进行填补，每完成一次回归预测，就将预测值放到原本的特征矩阵中，再继续填补下一个特征
for i in sortindex:
    # 构建我们的新特征矩阵和新标签
    df = X_missing_reg  # 充当中间数据集
    fillc = df.iloc[:, i]  # 缺失值最少的特征列
    # 除了第 i 特征列，剩下的特征列+原有的完整标签 = 新的特征矩阵
    df = pd.concat([df.drop(df.columns[i], axis=1), pd.DataFrame(y_full)], axis=1)
    # 在新特征矩阵中，对含有缺失值的列，进行0的填补 ，没循环一次，用0填充的列越来越少
    df_0 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=0).fit_transform(df)
    # 找出训练集和测试集
    # 标签
    Ytrain = fillc[fillc.notnull()]  # 没有缺失的部分，就是 Y_train
    Ytest = fillc[fillc.isnull()]  # 不是需要Ytest的值，而是Ytest的索引
#     print(Ytrain,Ytest)
    # 特征矩阵
#     Xtrain = df_0[Ytrain.index, :]
    Xtrain = df_0[Ytrain.index]
    Xtest = df_0[Ytest.index, :]  # 有缺失值的特征情况
    rfc = RandomForestRegressor(n_estimators=100)  # 实例化
    rfc = rfc.fit(Xtrain, Ytrain)  # 训练
    Ypredict = rfc.predict(Xtest)  # 预测结果，就是要填补缺失值的值
    # 将填补好的特征返回到我们的原始的特征矩阵中
    X_missing_reg.loc[X_missing_reg.iloc[:, i].isnull(), X_missing_reg.columns[i]] = Ypredict
# 最后，再次查看缺失值是否全部被替换
missing2 = X_missing_reg.isna().sum()
missing2 = pd.DataFrame(data={'列名': missing2.index, '缺失值个数': missing2.values})
# 通过~取反，选取不包含数字0的行
missing3=missing2[~missing2['缺失值个数'].isin([0])]
print(missing2)
print(missing3)
# Out:
#               列名  缺失值个数
# 0   C.SUBJECT_ID      0
# 1            ALT      0
# 2            AST      0
# 3            BUN      0
# 4             CL      0
# 5            GLU      0
# 6            HCT      0
# 7     Hemoglobin      0
# 8            INR      0
# 9              K      0
# 10            Na      0
# 11           PLT      0
# 12            PT      0
# 13           PTT      0
# 14          TBIL      0
# 15           WBC      0
# 16    creatinine      0
# 17           gcs      0
# 18          hco3      0
# 19            hr      0
# 20          pain      0
# 21          resp      0
# 22          spo2      0
# 23          temp      0
# Empty DataFrame
# Columns: [列名, 缺失值个数]
# Index: []

# %%
X_missing_reg
# Out:
#       C.SUBJECT_ID        ALT         AST    BUN          CL         GLU  \
# 0              109  80.000000  136.000000   48.0  110.333333  101.666667
# 1              111  45.000000   52.000000   30.5  125.500000  119.000000
# 2              124  15.538333   18.670000  107.5  117.000000  118.000000
# 3              188  41.000000   65.000000   29.5  116.500000  240.500000
# 4              357  19.000000   20.000000   24.5  110.000000  143.000000
# ...            ...        ...         ...    ...         ...         ...
# 1913         99817  51.500000  104.500000   52.0  108.000000  102.500000
# 1914         99847  21.178333   21.240000   28.0  103.000000  169.500000
# 1915         99863  24.870000   21.626667   13.5  105.000000  282.666667
# 1916         99923  75.000000  125.000000   79.0   91.500000  115.500000
# 1917         99939  18.000000   16.000000  142.5  105.000000  163.500000
#
#        HCT  Hemoglobin    INR      K  ...      TBIL        WBC  creatinine  \
# ...

# %%
data = remcolumns(del_rows_df)
data = data[['C.SUBJECT_ID','Death']]
data
# Out:
#       C.SUBJECT_ID  Death
# 0              109      1
# 1              111      1
# 2              124      1
# 3              188      1
# 7              357      0
# ...            ...    ...
# 3260         99817      1
# 3262         99847      0
# 3263         99863      0
# 3267         99923      0
# 3268         99939      0
#
# [1918 rows x 2 columns]

# %%
data = X_missing_reg.merge(data,on=['C.SUBJECT_ID'],how='left')
data
# Out:
#       C.SUBJECT_ID        ALT         AST    BUN          CL         GLU  \
# 0              109  80.000000  136.000000   48.0  110.333333  101.666667
# 1              111  45.000000   52.000000   30.5  125.500000  119.000000
# 2              124  15.538333   18.670000  107.5  117.000000  118.000000
# 3              188  41.000000   65.000000   29.5  116.500000  240.500000
# 4              357  19.000000   20.000000   24.5  110.000000  143.000000
# ...            ...        ...         ...    ...         ...         ...
# 1913         99817  51.500000  104.500000   52.0  108.000000  102.500000
# 1914         99847  21.178333   21.240000   28.0  103.000000  169.500000
# 1915         99863  24.870000   21.626667   13.5  105.000000  282.666667
# 1916         99923  75.000000  125.000000   79.0   91.500000  115.500000
# 1917         99939  18.000000   16.000000  142.5  105.000000  163.500000
#
#        HCT  Hemoglobin    INR      K  ...        WBC  creatinine       gcs  \
# ...

# %%
((data.isnull().sum())/data.shape[0]).sort_values(ascending=False).map(lambda x:"{:.2%}".format(x))
# Out:
# C.SUBJECT_ID    0.00%
# PTT             0.00%
# temp            0.00%
# spo2            0.00%
# resp            0.00%
# pain            0.00%
# hr              0.00%
# hco3            0.00%
# gcs             0.00%
# creatinine      0.00%
# WBC             0.00%
# TBIL            0.00%
# PT              0.00%
# ALT             0.00%
# PLT             0.00%
# Na              0.00%
# K               0.00%
# INR             0.00%
# Hemoglobin      0.00%
# HCT             0.00%
# GLU             0.00%
# CL              0.00%
# BUN             0.00%
# AST             0.00%
# Death           0.00%
# dtype: object

# %%
data.to_csv('row_data.csv')

# %% [markdown]
# ## 去掉缺失值过多的字段，后进行插补的结果

# %%
# data = pd.read_excel(r"C:\Users\xw\Desktop\预测数据.xlsx")# 导入原始数据
# data = remcolumns(del_rows_df)
data = del_rows(del_cols_df)
data = data.reset_index()

target = data['gcs']
# 这里的‘gcs’是指没有数据缺失的那一列的名称，选取一列即可
# 如果每一列的数据都缺失了，可以再创建一列都是1的完整数据并填写名称
features = data.iloc[:,1:-1]
#注意这里没有我没有取最后一列，可根据自己的情况改动

X_full, y_full = features,target
n_samples = X_full.shape[0] # 样本
n_features = X_full.shape[1] # 特征
print(n_samples)
print(n_features)
 
#首先确定我们希望放入的缺失值数据的比例，在这里我假设是50%，可以自己改动
rng = np.random.RandomState(0)
missing_rate = 0.5
n_missing_samples = int(np.floor(n_samples * n_features *missing_rate))
#np.floor  向下取整
#所有数据要随机遍布在数据集的各行各列当中，而一个确实的数据会需要一盒行索引和一个列索引
#如果能够创造一个数组，就可以利用索引来赋空值
 
X_missing_reg = X_full.copy()
# 查看缺失情况
missing = X_missing_reg .isna().sum()
missing = pd.DataFrame(data={'特征': missing.index,'缺失值个数':missing.values})
#通过~取反，选取不包含数字0的行
missing = missing[~missing['缺失值个数'].isin([0])]
# 缺失比例
missing['缺失比例'] =  missing['缺失值个数']/X_missing_reg .shape[0]
# print(missing['缺失比例'])
X_df = X_missing_reg.isnull().sum()
# 得出列名 缺失值最少的列名 到 缺失值最多的列名
colname = X_df[~X_df.isin([0])].sort_values().index.values

# 缺失值从小到大的特征顺序
sortindex = []
for i in colname:
    sortindex.append(X_missing_reg.columns.tolist().index(str(i)))
# 遍历所有的特征，从缺失最少的开始进行填补，每完成一次回归预测，就将预测值放到原本的特征矩阵中，再继续填补下一个特征
for i in sortindex:
    # 构建我们的新特征矩阵和新标签
    df = X_missing_reg  # 充当中间数据集
    fillc = df.iloc[:, i]  # 缺失值最少的特征列
    # 除了第 i 特征列，剩下的特征列+原有的完整标签 = 新的特征矩阵
    df = pd.concat([df.drop(df.columns[i], axis=1), pd.DataFrame(y_full)], axis=1)
    # 在新特征矩阵中，对含有缺失值的列，进行0的填补 ，没循环一次，用0填充的列越来越少
    df_0 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=0).fit_transform(df)
    # 找出训练集和测试集
    # 标签
    Ytrain = fillc[fillc.notnull()]  # 没有缺失的部分，就是 Y_train
    Ytest = fillc[fillc.isnull()]  # 不是需要Ytest的值，而是Ytest的索引
#     print(Ytrain,Ytest)
    # 特征矩阵
#     Xtrain = df_0[Ytrain.index, :]
    Xtrain = df_0[Ytrain.index]
    Xtest = df_0[Ytest.index, :]  # 有缺失值的特征情况
    rfc = RandomForestRegressor(n_estimators=100)  # 实例化
    rfc = rfc.fit(Xtrain, Ytrain)  # 训练
    Ypredict = rfc.predict(Xtest)  # 预测结果，就是要填补缺失值的值
    # 将填补好的特征返回到我们的原始的特征矩阵中
    X_missing_reg.loc[X_missing_reg.iloc[:, i].isnull(), X_missing_reg.columns[i]] = Ypredict
# 最后，再次查看缺失值是否全部被替换
missing2 = X_missing_reg.isna().sum()
missing2 = pd.DataFrame(data={'列名': missing2.index, '缺失值个数': missing2.values})
# 通过~取反，选取不包含数字0的行
missing3=missing2[~missing2['缺失值个数'].isin([0])]
print(missing2)
print(missing3)
# Out:
# 3210
# 21
#               列名  缺失值个数
# 0   C.SUBJECT_ID      0
# 1            BUN      0
# 2             CL      0
# 3            GLU      0
# 4            HCT      0
# 5     Hemoglobin      0
# 6            INR      0
# 7              K      0
# 8             Na      0
# 9            PLT      0
# 10            PT      0
# 11           PTT      0
# 12           WBC      0
# 13    creatinine      0
# 14           gcs      0
# 15          hco3      0
# 16            hr      0
# 17          pain      0
# 18          resp      0
# 19          spo2      0
# 20          temp      0
# Empty DataFrame
# Columns: [列名, 缺失值个数]
# Index: []

# %%
data = del_rows(del_cols_df)
data = data[['C.SUBJECT_ID','Death']]
data
# Out:
#       C.SUBJECT_ID  Death
# 0              109      1
# 1              111      1
# 2              124      1
# 3              188      1
# 4              222      0
# ...            ...    ...
# 3266         99899      1
# 3267         99923      0
# 3268         99939      0
# 3269         99973      0
# 3270         99992      0
#
# [3210 rows x 2 columns]

# %%
data = X_missing_reg.merge(data,on=['C.SUBJECT_ID'],how='left')
data
# Out:
#       C.SUBJECT_ID    BUN          CL         GLU        HCT  Hemoglobin  \
# 0              109   48.0  110.333333  101.666667  23.600000    7.300000
# 1              111   30.5  125.500000  119.000000  40.400000   13.100000
# 2              124  107.5  117.000000  118.000000  28.700000    9.850000
# 3              188   29.5  116.500000  240.500000  28.100000    9.200000
# 4              222   19.0  104.000000   95.000000  22.800000    7.700000
# ...            ...    ...         ...         ...        ...         ...
# 3205         99899   41.0   92.000000  126.000000  19.400000    6.600000
# 3206         99923   79.0   91.500000  115.500000  31.500000   10.800000
# 3207         99939  142.5  105.000000  163.500000  22.400000    7.866667
# 3208         99973   18.5  116.500000   91.000000  29.000000    9.350000
# 3209         99992   56.0  104.000000  110.000000  28.933333   11.000000
#
#          INR      K          Na    PLT  ...        WBC  creatinine       gcs  \
# ...

# %%
data.to_csv('col_data.csv')
