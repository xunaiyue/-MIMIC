# %%
import numpy as np
import pandas as pd
import pickle
from collections import OrderedDict
import sqlalchemy
import psycopg2

# %%
# %load_ext sql
# %sql mysql://root:112928@localhost/mimic
# %sql use mimic
# Out:
#  * mysql://root:***@localhost/mimic
# 0 rows affected.
# []

# %%
akf_id = %sql SELECT DISTINCT * FROM `diagnoses_icd` WHERE ICD9_CODE IN ('5849','5848')
# Out:
#  * mysql://root:***@localhost/mimic
# 9174 rows affected.

# %%
akf_id
# Out:
# [(6, 3, 145834, 3, '5849'),
#  (45, 9, 150750, 4, '5849'),
#  (115, 21, 109451, 4, '5849'),
#  (308, 38, 185910, 4, '5849'),
#  (404, 52, 190797, 3, '5849'),
#  (545, 68, 108329, 5, '5849'),
#  (557, 68, 170467, 6, '5849'),
#  (842, 105, 161160, 8, '5849'),
#  (850, 106, 145167, 3, '5849'),
#  (1364, 109, 183350, 2, '5849'),
#  (1453, 111, 155897, 2, '5849'),
#  (1480, 112, 173177, 6, '5849'),
#  (1535, 117, 164853, 4, '5849'),
#  (1585, 124, 134369, 2, '5849'),
#  (1607, 124, 138376, 9, '5849'),
#  (1829, 145, 198161, 11, '5849'),
#  (1944, 156, 168847, 5, '5849'),
#  (2112, 171, 153112, 4, '5849'),
#  (2267, 188, 123860, 3, '5849'),
#  (2384, 191, 136614, 5, '5849'),
#  (2397, 191, 142081, 3, '5849'),
#  (2436, 197, 129890, 2, '5849'),
#  (2483, 201, 161473, 6, '5849'),
#  (2489, 202, 108295, 3, '5849'),
#  (2546, 209, 190711, 4, '5849'),
#  (2578, 211, 101148, 6, '5849'),
#  (2625, 214, 197273, 5, '5849'),
#  (2732, 222, 188038, 2, '5849'),
#  (2888, 236, 191151, 4, '5849'),
# ...

# %%
id_columns = akf_id.field_names

# %%
akf_id = pd.DataFrame(akf_id,columns=id_columns)
akf_id
# Out:
#       ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0          6           3   145834        3      5849
# 1         45           9   150750        4      5849
# 2        115          21   109451        4      5849
# 3        308          38   185910        4      5849
# 4        404          52   190797        3      5849
# ...      ...         ...      ...      ...       ...
# 9169  650939       99982   112748        2      5849
# 9170  650964       99982   183791        5      5849
# 9171  650977       99983   117390        2      5849
# 9172  651000       99991   151118        4      5849
# 9173  651018       99992   197084        5      5849
#
# [9174 rows x 5 columns]

# %%
akf_id['SUBJECT_ID'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9169    False
# 9170     True
# 9171    False
# 9172    False
# 9173    False
# Name: SUBJECT_ID, Length: 9174, dtype: bool

# %%
akf_id[~akf_id['SUBJECT_ID'].duplicated()]
# Out:
#       ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0          6           3   145834        3      5849
# 1         45           9   150750        4      5849
# 2        115          21   109451        4      5849
# 3        308          38   185910        4      5849
# 4        404          52   190797        3      5849
# ...      ...         ...      ...      ...       ...
# 9168  650930       99973   150202        2      5849
# 9169  650939       99982   112748        2      5849
# 9171  650977       99983   117390        2      5849
# 9172  651000       99991   151118        4      5849
# 9173  651018       99992   197084        5      5849
#
# [7735 rows x 5 columns]

# %%
sub_id = akf_id[~akf_id['SUBJECT_ID'].duplicated()]
sub_id['HADM_ID'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9168    False
# 9169    False
# 9171    False
# 9172    False
# 9173    False
# Name: HADM_ID, Length: 7735, dtype: bool

# %%
sub_id[~sub_id['HADM_ID'].duplicated()]
# Out:
#       ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0          6           3   145834        3      5849
# 1         45           9   150750        4      5849
# 2        115          21   109451        4      5849
# 3        308          38   185910        4      5849
# 4        404          52   190797        3      5849
# ...      ...         ...      ...      ...       ...
# 9168  650930       99973   150202        2      5849
# 9169  650939       99982   112748        2      5849
# 9171  650977       99983   117390        2      5849
# 9172  651000       99991   151118        4      5849
# 9173  651018       99992   197084        5      5849
#
# [7735 rows x 5 columns]

# %%
akf_id[~akf_id['HADM_ID'].duplicated()]
# Out:
#       ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0          6           3   145834        3      5849
# 1         45           9   150750        4      5849
# 2        115          21   109451        4      5849
# 3        308          38   185910        4      5849
# 4        404          52   190797        3      5849
# ...      ...         ...      ...      ...       ...
# 9169  650939       99982   112748        2      5849
# 9170  650964       99982   183791        5      5849
# 9171  650977       99983   117390        2      5849
# 9172  651000       99991   151118        4      5849
# 9173  651018       99992   197084        5      5849
#
# [9173 rows x 5 columns]

# %%
hadm_id = akf_id[~akf_id['HADM_ID'].duplicated()]

# %%
hadm_id['HADM_ID']
# Out:
# 0       145834
# 1       150750
# 2       109451
# 3       185910
# 4       190797
#          ...
# 9169    112748
# 9170    183791
# 9171    117390
# 9172    151118
# 9173    197084
# Name: HADM_ID, Length: 9173, dtype: int64

# %%
sub_id_num = sub_id[~sub_id['HADM_ID'].duplicated()]

# %% [markdown]
# -- 计算年龄
# select ad.subject_id,ad.hadm_id,
# year(ad.admittime) - year(pat.dob) as age
# from admissions ad, patients pat
# where ad.SUBJECT_ID = pat.SUBJECT_ID;

# %%
age_id =  %sql select ad.subject_id,ad.hadm_id,year(ad.admittime) - year(pat.dob) as age from admissions ad, patients pat where ad.SUBJECT_ID = pat.SUBJECT_ID;
# Out:
#  * mysql://root:***@localhost/mimic
# 58976 rows affected.

# %%
age_id_col = age_id.field_names

# %%
age_id_num = pd.DataFrame(age_id,columns=age_id_col)

# %%
# 计算 SUBJECT_ID 相同，即病人相同
age_id_num['label'] = age_id_num['subject_id'].apply(lambda subject: 1 if int(subject) in sub_id_num['SUBJECT_ID'].values else 0 )
age_id_num['label']

# %%
# 计算 HADM_ID 相同，即进入医院编号相同
age_id_num['label'] = age_id_num['hadm_id'].apply(lambda subject: 1 if int(subject) in sub_id_num['HADM_ID'].values else 0 )
age_id_num['label']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 58971    0
# 58972    1
# 58973    1
# 58974    0
# 58975    0
# Name: label, Length: 58976, dtype: int64

# %%
# 计算 HADM_ID 相同，即进入医院编号相同
age_id_num['label'] = age_id_num['hadm_id'].apply(lambda subject: 1 if int(subject) in hadm_id['HADM_ID'].values else 0 )
age_id_num['label']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 58971    0
# 58972    1
# 58973    1
# 58974    0
# 58975    0
# Name: label, Length: 58976, dtype: int64

# %%
age_id_num[age_id_num['label']==1]
# Out:
#        subject_id  hadm_id  age  label
# 1               3   145834   76      1
# 7               9   150750   41      1
# 18             21   109451   87      1
# 39             38   185910   76      1
# 50             52   190797   39      1
# ...           ...      ...  ...    ...
# 58967       99982   112748   66      1
# 58969       99982   183791   66      1
# 58970       99983   117390   79      1
# 58972       99991   151118   47      1
# 58973       99992   197084   66      1
#
# [9173 rows x 4 columns]

# %%
age_hadmid = age_id_num[age_id_num['label']==1]

# %%
Age_hadmid = age_hadmid[age_hadmid.columns[0:-1]]

# %%
# Age_hadmid.to_csv('Age_hadmid.csv',index=False)

# %%
sex_subid = Age_hadmid['subject_id'].values
type(sex_subid)
# Out:
# numpy.ndarray

# %%
sex_subid
# Out:
# array([    3,     9,    21, ..., 99983, 99991, 99992], dtype=int64)

# %% [markdown]
# -- 查看性别
# select GENDER from patients where SUBJECT_ID = 2;

# %%
# 查看性别
gender_id =  %sql select SUBJECT_ID, GENDER from patients;
# Out:
#  * mysql://root:***@localhost/mimic
# 46520 rows affected.

# %%
gender_id = pd.DataFrame(gender_id,columns=['SUBJECT_ID','GENDER'])

# %%
gender_id['label_subid'] = gender_id['SUBJECT_ID'].apply(lambda subject: 1 if int(subject) in Age_hadmid['subject_id'].values else 0 )

# %%
gender_sub_id = gender_id[gender_id['label_subid']==1]

# %%
gender_subid = gender_sub_id[gender_sub_id.columns[0:-1]]

# %%
gender_subid
# Out:
#        SUBJECT_ID GENDER
# 1               3      M
# 7               9      M
# 17             21      M
# 33             38      M
# 44             52      M
# ...           ...    ...
# 46512       99973      F
# 46513       99982      M
# 46514       99983      M
# 46516       99991      M
# 46517       99992      F
#
# [7735 rows x 2 columns]

# %%
Age_hadmid.merge(gender_subid,left_on='subject_id',right_on='SUBJECT_ID')
# Out:
#       subject_id  hadm_id  age  SUBJECT_ID GENDER
# 0              3   145834   76           3      M
# 1              9   150750   41           9      M
# 2             21   109451   87          21      M
# 3             38   185910   76          38      M
# 4             52   190797   39          52      M
# ...          ...      ...  ...         ...    ...
# 9168       99982   112748   66       99982      M
# 9169       99982   183791   66       99982      M
# 9170       99983   117390   79       99983      M
# 9171       99991   151118   47       99991      M
# 9172       99992   197084   66       99992      F
#
# [9173 rows x 5 columns]

# %%
Age_Gender_subId = Age_hadmid.merge(gender_subid,left_on='subject_id',right_on='SUBJECT_ID')

# %%
Age_Gender_subId.to_csv('Age_Gender_subId.csv',index=False)
